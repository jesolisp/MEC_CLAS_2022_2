# %% [markdown]
# <img src="../figs/logo_ENESJ.png" width=140 height=120 />
#
# # Mecánica clásica
# ##  Semestre 2022-2
#
# ### Profr. Jesús Emmanuel Solís Pérez
# ### jsolisp@unam.mx
# ---

# %% [markdown]
# # Unidad III. Dinámica de una partícula.
#
# **Fuerza**. Interacción con un objeto.
#
# **Fuerza de contacto**. Implica contacto físico entre dos objetos.
#
# **Fuerza de campo**. No involucra contacto físico entre dos objetos.
#
# Las únicas fuerzas *fundamentales* que podemos encontrar en la naturaleza son fuerzas de campo:
#  1. fuerzas gravitacionales entre objetos
#  2. fuerzas electromagnéticas entre cargas eléctricas,
#  3. fuerzas fuertes entre partículas subatómicas y
#  4. fuerzas débiles que surgen en ciertos procesos de decaimiento radiactivo.
#
# ## Primera ley de Newton (ley de la inercia)
# >Si un objeto no interactúa con otros objetos, es posible identificar un marco de referencia en el que el objeto tiene aceleración cero.
#
# Este marco de referencia se llama **marco de referencia inercial**.
#
# >Cualquier marco de referencia que se mueve con velocidad constante en relación con un marco inercial es, en sí mismo, un marco inercial.
#
# La Tierra no es un marco inercial debido a su movimiento orbital en torno al Sol y su movimiento rotacional sobre su propio eje. Sin embargo, al involucrar aceleraciones centrípetas se pueden despreciar ya que son pequeñas en comparación con *g*. Por consiguiente, la Tierra representa un marco inercial.
#
# > Un objeto en reposo se mantiene en reposo y un objeto en movimiento continúa en movimiento con una velocidad constante (esto es, con una rapidez constante en una línea recta) al no haber fuerzas externas bajo un marco de referencia inercial.
#
# **Nota**. Cuando ninguna fuerza actúa sobre un objeto, la aceleración del objeto es cero.
#
# Definimos entonces como **inercia** a la resistencia que presenta un objeto por cambiar su velocidad y a la **fuerza** como aquello que causa un cambio en el movimiento de un objeto.
#
# **Masa**. Es la propiedad de un objeto que indicia cuánta resistencia presenta un objeto para cambiar su velocidad. Es independiente del entorno del objeto y del método utilizado para medirla. Recordemos también que es una cantidad *escalar*.
#
# **Nota**. La masa y el peso son dos cantidades diferentes.
#    * **Peso**. Es igual a la magnitud de la fuerza gravitacional ejercida sobre el objeto y varía con la posición.
#
# ## Segunda ley de Newton
#
# > La aceleración de un objeto es directamente proporcional a la fuerza neta que actúa sobre él e inversamente
# proporcional a su masa cuando se ve desde un marco de refencia inercial:
#
# \begin{equation}
#  \label{segln}
#  \overrightarrow{\bf a} \varpropt \frac{\sum \overrightarrow{\bf F}}{m}.
# \end{equation}
#
# De \eqref{segln}, relacionamos la masa, aceleración y fuerza si se elige una constante de proporcionalidad igual a uno, *i.e*:
#
# \begin{equation}
#  \label{segln2}
#  \sum \overrightarrow{\bf F} = m\cdot \overrightarrow{\bf a},
# \end{equation}
#
# donde $\sum \overrightarrow{\bf F}$ denota la fuerza neta (suma vectorial de todas las fuerzas que actúan sobre el objeto).
#
# **Tarea**. ¿Cuándo es válida la Ec. \eqref{segln2}?
#
# La Ec. \eqref{segln2} es una representación vectorial y es equivalente a una forma de componentes:
#
# \begin{equation}
#  \sum F_{x} = m\cdot a_{x}, \quad \sum F_{y} = m\cdot a_{y}, \quad \sum F_{z} = m\cdot a_{z}.
# \end{equation}
#
# La unidad de fuerza es el **newton**:
#
# \begin{equation}
#  1 \text{N} \equiv 1 \text{kg}\cdot\text{m}/\text{s}^{2}.
# \end{equation}
#
# Lo anterior nos indica la fuerza que actua sobre un objeto de 1kg de masa y produce una aceleración de 1$\text{kg}\cdot\text{m}/\text{s}^{2}$.
#
# ---
#
# ## Ejemplo 1
# Un disco de hockey que tiene una masa de $0.30$ kg se desliza sobre la superficie horizontal sin fricción de una pista de patinaje. Dos bastones de hockey golpean el disco simultáneamente como se muestra en la siguiente figura, y ejercen las fuerzas sobre el disco. La fuerza $\overrightarrow{\bf F_{1}}$ tiene una magnitud de $0.5$ N y la fuerza $\overrightarrow{\bf F_{2}}$ tiene una magnitud de $8.0$ N. Determine tanto la magnitud como la dirección de la aceleración del disco.
#
# <img src="../figs/diagrama_ejercicio.png" width=340 height=320 />

# %% [markdown]
# ---
# ## Ejercicios
# 1. Un objeto de $3$ kg se somete a una aceleración conocida por $\overrightarrow{\bf a} = (2 \hat{i} + 5 \hat{j})$ $m/s^{2}$. Encuentre la fuerza resultante que actúa sobre él y la magnitud de la fuerza resultante.
# 2. Para modelar una nave espacial, el motor de un cohete de juguete se sujeta firmemente a un gran disco que puede
# deslizar con fricción despreciable sobre una superficie horizontal, que se toma como plano $xy$. El disco de $4~ kg$ tiene una velocidad de $3\hat{i}~ m/s$ en un instante. Ocho segundos después, su velocidad es $(8\hat{i} + 10\hat{j})~m/s$. Si supone que el motor de cohete ejerce una fuerza horizontal constante, encuentre:
#  1. las componentes de la fuerza
#  2. su magnitud.
# 4. La rapidez promedio de una molécula de nitrógeno en el aire es aproximadamente $6.7 \times 10^{2}~ m/s$ y su masa es $4.68 \times10^{-26}~ kg$.
#  1. Si una molécula de nitrógeno tarda $3 \times 10^{-13}~ s$ en golpear una pared y rebotar con la misma rapidez pero moviéndose en la dirección opuesta, ¿cuál es la aceleración promedio de la molécula durante este intervalo de tiempo?
#  2. ¿Qué fuerza promedio ejerce la molécula sobre la pared?
# 5. Un electrón de $9.11\times10^{-31}~ kg$ de masa tiene una rapidez inicial de $3\times 10^{5}~ m/s$. Viaja en línea recta y su rapidez aumenta a $7\times 10^{5}~ m/s$ en una distancia de $5~ cm$. Si supone que su aceleración es constante,
#  1. determine la fuerza que se ejerce sobre el electrón
#  2. compare esta fuerza con el peso del electrón, que se ignoró.
# 6. Una mujer pesa 120 lb. Determine:
#  1. su peso en newtons
#  2. su masa en kilogramos.
#
# 7.  Además de su peso, un objeto de $2.8~ kg$ está sometido a otra fuerza constante. El objeto parte del reposo y en $1.2~ s$ experimenta un desplazamiento de ($4.2 \hat{i} - 3.3 \hat{j})~ m/s$, donde la dirección de $\hat{j}$ es la dirección vertical hacia arriba. Determine la otra fuerza.
#
# 8. Dos fuerzas $\overrightarrow{F}_{1}$ y $\overrightarrow{F}_{2}$ actúan sobre un objeto de $5~ kg$. Si toma $F_{1} = 20~ N$ y $\overrightarrow{F}_{2} = 15~ N$, encuentre las aceleraciones en a) y b) de la siguiente figura:
#
# <img src="../figs/fuerzas_ejercicio.png" width=540 height=320 />
#
# 9. Tres fuerzas que actúan sobre un objeto se proporcionan por $\overrightarrow{F}_{1} = (-2\hat{i} + 2\hat{j})~N$, $\overrightarrow{F}_{2} = (5\hat{i} - 3\hat{j})~N$ y $\overrightarrow{F}_{3} = (-45\hat{i})~N$. El objeto experimenta una aceleración de $3.75~ m/s^{2}$ de magnitud.
#  * ¿Cuál es la dirección de la aceleración?
#  * ¿Cuál es la masa del objeto?
#  * Si el objeto inicialmente está en reposo, ¿cuál es su rapidez después de $10~ s$?
#  * ¿Cuáles son las componentes de velocidad del objeto después de $10~s$?
#
# 10. Un trabajador que empuja un bote, un modo de transporte muy eficiente, a través de un lago tranquilo. Empuja paralelo a la longitud de la pértiga ligera y ejerce sobre el fondo del lago una fuerza de 240 N. Suponga que la pértiga se encuentra en el plano vertical que contiene la quilla del bote. En algún momento, la pértiga forma un ángulo de $35.0^{°}$ con la vertical y el agua ejerce una fuerza de arrastre horizontal de $47.5~N$ sobre el bote, opuesta a su velocidad hacia adelante de $0.857~ m/s$ de magnitud. La masa del bote, que incluye su carga y al trabajador es de $370~kg$.
#  * El agua ejerce una fuerza de flotación vertical hacia arriba sobre el bote. Encuentre la magnitud de esta fuerza.
#  * Modele las fuerzas como constantes en un intervalo corto de tiempo para encontrar la velocidad del bote $0.45~s$ después del momento descrito.
#
# 11. Un objeto de $3~kg$ es móvil en un plano, con sus coordenadas $x$ y $y$ conocidas mediante $x=5t^{2} - 1$ y $y = 3t^{3}+2$, donde $x$ y $y$ están en metros y $t$ en segundos. Encuentre la magnitud de la fuerza neta que actúa en este objeto en $t=2~s$.
#
# 12. La distancia entre dos postes de teléfono es de $50~m$. Cuando un ave de $1~kg$ se posa sobre el alambre del teléfono a la mitad entre los postes, el alambre se comba $0.2~m$. Dibuje un diagrama de cuerpo libre del ave. ¿Cuánta tensión produce el ave en el alambre? Ignore el peso del alambre.
#
# > comba. 1. f. Inflexión que toman algunos cuerpos sólidos cuando se encorvan; como los maderos, las barras, etc.

# %% [markdown]
# ---
# ## Fuerza gravitacional y peso
# La Tierra ejerce una fuerza sobre todos los objetos. Esta fuerza es llamada **fuerza gravitacional** y se denota como $\overrightarrow{\bf F}_{g}$. Dicha fuerza se dirige hacia el centro de la Tierra y su magnitud se llama **peso** del objeto.
#
# Cuando un objeto en caída libre experimenta una aceleración $\overrightarrow{\bf g}$ que actúa hacia el centro de la Tierra. Aplicando la segunda Ley de Newton
#
# \begin{equation}
#  \overrightarrow{\bf F} = m \overrightarrow{\bf a},
# \end{equation}
#
# a un objeto en caída libre de masa $m$, con $\overrightarrow{\bf a} = \overrightarrow{\bf g}$ y $\sum \overrightarrow{\bf F} = \overrightarrow{\bf F}_{g}$, obtenemos:
#
# \begin{equation}
#  \overrightarrow{\bf F}_{g} = m \overrightarrow{\bf g}.
# \end{equation}
#
# Por lo tanto, el peso de un objeto queda definido como la magnitud de $\overrightarrow{\bf F}_{g}$
#
# \begin{equation}
#  {F}_{g} = mg.
# \end{equation}
#
# La ecuación anterior cuantifica la fuerza gravitacional sobre un objeto. También se puede aplicar para calcular la magnitud de la fuerza gravitacional para un objeto fijo o para un objeto sobre el que actúan varias fuerzas.
#
# ---
# # Tercera Ley de Newton
# > Si dos objetos interactúan, la fuerza $\overrightarrow{\bf F}_{12}$ que ejerce el objeto 1 sobre el objeto 2 es igual en magnitud y opuesta en dirección a la fuerza $\overrightarrow{\bf F}_{21}$ que ejerce el objeto 2 sobre el objeto 1:
#
# \begin{equation}
#  \overrightarrow{\bf F}_{12} = -\overrightarrow{\bf F}_{21},
# \end{equation}
#
# donde $\overrightarrow{\bf F}_{ab}$ significa "la fuerza que se ejerce *por* $a$ *sobre* $b$".
#
# Considere la siguiente imagen
#
# <img src="../figs/accion-reaccion.jpg" width=340 height=320 />
#
# La fuerza que el pie ejerce sobre el balón se llama *fuerza de acción*, mientras que la fuerza del balón sobre el pie se llama *fuerza de reacción*.
#
# > En todos los casos, las fuerzas de acción y reacción actúan sobre objetos diferentes y deben ser del mismo tipo (gravitacional, eléctrica, etcétera).
#
# Los **diagramas de cuerpo libre** es una representación gráfica que aisla aquellas fuerzas sobre el objeto y elimina las otras fuerzas del análisis.
#
# ---
# # Aplicaciones de las Leyes de Newton
#
# ## Partícula en equilibrio
# Se dice que una **partícula está en equilibrio** si la aceleración del objeto (representado como partícula) es cero. En este modelo, la fuerza neta sobre el objeto es cero:
#
# \begin{equation}
#  \sum \overrightarrow{\bf F} = 0.
# \end{equation}
#
#
# ## Partícula bajo una fuerza neta
# Si un objeto experimenta una aceleración, es posible analizar su movimiento con el modelo de partícula bajo una fuerza neta. Para ello suele utilizarse la segunda Ley de Newton.
#
# Considere la siguiente figura
#
# <img src="../figs/jalando_objeto.png" width=340 height=320 />
#
# Calcule:
#  * la aceleración de la caja
#  * la fuerza que el suelo ejerce sobre ella
#
# Aplicando la segunda Ley de Newton en forma de componentes, podemos observar que la única que fuerza que actúa en la dirección $x$ es $\overrightarrow{\bf T}$
#
# \begin{equation}
#  \sum F_{x} = T = ma_{x} \quad \Rightarrow \quad a_{x} = \frac{T}{m}.
# \end{equation}

# %% [markdown]
# ## Ejemplo 2
# Un semáforo con un peso de $122~N$ cuelga de un cable unido a otros dos cables sostenidos a un soporte como se muestra a continuación
#
# <img src="../figs/semaforo_ejercicio.png" width=540 height=420 />
#
# Los cables superiores forman ángulos de $37^{°}$ y $53^{°}$ con respecto a la horizontal. Desafortunadamente, estos cables no son tan fuertes en contraste con el cable vertical. Por lo tanto, se romperán si la tensión en ellos supera los $100~ N$. ¿El semáforo permanecerá colgado, o alguno de los cables se romperá?

# %% [markdown]
# # Ejercicios
# 1. Un automóvil de masa $m$ está sobre un camino cubierto con hielo inclinada en un ángulo $\theta$, como se muestra en la siguiente figura.
#
# <img src="../figs/auto_pendiente.jpg" width=440 height=320 />
#
#  * Encuentre la aceleración del automóvil, si supone que la pista no tiene fricción.
#  * Considere que el automóvil se libera desde el reposo en lo alto del plano y que la distancia desde la defensa frontal del automóvil hasta el fondo del plano inclinado es $d$. ¿Cuánto tarda la defensa frontal en llegar al fondo de la colina, y cuál es la rapidez del automóvil cuando llega ahí?
#
# 2. Dos bloques de masas $m_{1}$ y $m_{2}$, con $m_{1}>m_{2}$, se colocan en contacto mutuo sobre una superficie horizontal sin fricción, como se muestra en la siguiente figura. Una fuerza horizontal constante $\overrightarrow{F}$ se aplica a $m_{1}$.
#
# <img src="../figs/ejercicio_masas.png" width=440 height=320 />
#
#    * Encuentre la magnitud de la aceleración del sistema.
#    * Determine la magnitud de la fuerza de contacto entre los dos bloques.
#
# 3. Cuando dos objetos de masas distintas cuelgan verticalmente sobre una polea sin fricción de masa despreciable, como en la siguiente figura, el dispositivo se llama *máquina de Atwood*. Se usa a veces en el laboratorio para calcular el valor de $g$. Determine la magnitud de la aceleración de dos objetos y la tensión en la cuerda sin peso.
#
# <img src="../figs/disp_act.png" width=140 height=220 />

# %% [markdown]
# ---
# # Fuerzas de fricción
# La resistencia al movimiento porque un objeto interactua con su entorno se le conoce como **fuerza de fricción**. Estas fuerzas están presentes en nuestro día a día por lo que no podemos considerar problemas ideales cuando tratamos de entender nuestro entorno.
#
# **Fuerza de fricción estática**. Fuerza $\overrightarrow{f}_{s}$ que actua sobre un objeto y evita que éste se desplace. La siguiente relación $f_{s}=F$ indica que el objeto no se mueve.
#
# Cuando un objeto está a punto de deslizarse, $f_{s}$ tiene su valor máximo $f_{s,\max}$. Esto implica que cuando $F$ supera a $f_{s,\max}$ el objeto se mueve.
#
# A la fuerza de fricción para un objeto en movimiento se le llama **fuerza de fricción cinética** y se denota por $\overrightarrow{f}_{k}$. Considere un objeto que se desplaza sobre un plano horizontal. Aquí, la fuerza neta $F-f_{k}$ en la dirección $x$ produce una aceleración hacia la derecha de acuerdo con la segunda ley de Newton.
#
# * La magnitud de la fuerza de fricción estática entre dos superficies en contacto tiene los valores
#
# \begin{equation}
#  f_{s} \leq \mu_{s}n,
# \end{equation}
#
# donde la constante adimensional $\mu_{s}$ se llama coeficiente de fricción estática y $n$ es la magnitud de la fuerza normal que ejerce una superficie sobre la otra. Cuando las superficies están a punto de deslizarse, implica que $f_{s} = f_{s,\max} \equiv \mu_{s}n$. A esto se le llama *movimiento inminente*.
#
# * La magnitud de la fuerza de fricción cinética que actúa entre dos superficies es
#
# \begin{equation}
#  f_{k} = \mu_{k}n,
# \end{equation}
#
# donde $\mu_{k}$ se llama coeficiente de fricción cinética.
#
# Encuentre los coeficientes de fricción de lo siguiente
#
# | |$\mu_s$ | $\mu_k$ |
# |:--------------------:|:--------------------:|:----------------------:|
# Hule sobre concreto | | |
# Acero sobre acero | | |
# Aluminio sobre acero | | |
# Vidrio sobre vidrio | | |
# Cobre sobre acero | | |
# Madera sobre madera | | |
# Madera encerada sobre nieve húmeda | | |
# Madera encerada sobre nieve seca | | |
# Metal sobre metal (lubricado) | | |
# Teflón sobre teflón | | |
# Hielo sobre hielo | | |
# Articulación sinovial en humanos | | |

# %% [markdown]
# ---
# # Ejemplo 3
# Suponga que se coloca un bloque sobre una superficie rugosa inclinada en relación con la horizontal, como se muestra en la siguiente figura.
#
# <img src="../figs/plano_inclinado_fs.png" width=440 height=220 />
#
# El ángulo de inclinación aumenta hasta que el bloque comienza a moverse. Demuestre que puede obtener $\mu_{s}$ al medir el ángulo crítico $\theta_c$ al que comienza a ocurrir este deslizamiento.
#
# ---
#
# # Ejemplo 4
#
# A un disco de hockey sobre un estanque congelado se le da una rapidez inicial de $20.0~ m/s$. Si el disco siempre permanece sobre el hielo y se desliza 115 m antes de llegar al reposo, determine el coeficiente de fricción cinética entre el disco y el hielo.

# %% [markdown]
# ---
# # Ejercicios
# 1. Un automóvil viaja a 50.0 mi/h en una autopista.
#  1. Si el coeficiente de fricción estática entre camino y llantas en un día lluvioso es 0.100, ¿cuál es la distancia mínima en la que el automóvil se detendrá?
#  2. ¿Cuál es la distancia de frenado cuando la superficie está seca y $\mu_{s} = 0.6$?
#
# 2. Un bloque de $25~kg$ al inicio está en reposo sobre una superficie horizontal. Se requiere una fuerza horizontal de $75~N$ para poner al bloque en movimiento, después de la cual se requiere una fuerza horizontal de $60~N$ para mantener al bloque en movimiento con rapidez constante. Hallar los coeficientes de fricción estática y cinética a partir de esta información.
#
# 3. Un bloque de $3~kg$ parte del reposo en lo alto de un plano inclinado $30°$ y se desliza una distancia de $2~m$ hacia abajo por el plano en $1.5~s$. Encuentre:
#  1. la magnitud de la aceleración del bloque,
#  2. el coeficiente de fricción cinética entre el bloque y el plano,
#  3. la fuerza de fricción que actúa sobre el bloque y
#  4. la rapidez del bloque después de deslizar 2.00 m.
#
# 4. Dos bloques unidos mediante una cuerda de masa despreciable se arrastran mediante una fuerza horizontal como se muestra a continuación:
#
# <img src="../figs/dos_bloques.png" width=440 height=220 />
#
# Suponga que $F = 68~N$, $m_{1} = 12~ kg$, $m_{2} = 18~ kg$ y el coeficiente de fricción cinética entre cada bloque y la superficie es 0.100.
#  1. Dibuje un diagrama de cuerpo libre para cada bloque.
#  2. Determine la tensión T y la magnitud de la aceleración del sistema.

# %% [markdown]
# ---
# # Videos de apoyo
# * [Primera Ley de Newton](https://www.youtube.com/watch?v=0T_t8srKHA8)
# * [13 Ejemplos de la Primera Ley de Newton](https://www.youtube.com/watch?v=J5lxAPthPd4)
# * [Segunda Ley de Newton](https://www.youtube.com/watch?v=BlfyfVe9W38)
# * [13 Ejemplos de la Segunda Ley de Newton](https://www.youtube.com/watch?v=km0gRXpKi2o)
